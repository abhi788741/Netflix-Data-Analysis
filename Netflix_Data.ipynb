# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\kapur\\Downloads\\netflix1.csv")
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
df.head(10)
# Out:
#   show_id     type                             title             director  \
# 0      s1    Movie              Dick Johnson Is Dead      Kirsten Johnson
# 1      s3  TV Show                         Ganglands      Julien Leclercq
# 2      s6  TV Show                     Midnight Mass        Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl        Bruno Garotti
# 4      s8    Movie                           Sankofa         Haile Gerima
# 5      s9  TV Show     The Great British Baking Show      Andy Devonshire
# 6     s10    Movie                      The Starling       Theodore Melfi
# 7    s939    Movie   Motu Patlu in the Game of Zones          Suhas Kadav
# 8     s13    Movie                      Je Suis Karl  Christian Schwochow
# 9    s940    Movie          Motu Patlu in Wonderland          Suhas Kadav
#
#           country date_added  release_year rating   duration  \
# 0   United States  9/25/2021          2020  PG-13     90 min
# ...

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
df["date_added"]=pd.to_datetime(df["date_added"])
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country date_added  release_year rating   duration  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   datetime64[ns]
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 686.8+ KB

# %%
df["years"]=df["date_added"].dt.year
df["years"]
# Out:
# 0       2021
# 1       2021
# 2       2021
# 3       2021
# 4       2021
#         ...
# 8785    2017
# 8786    2018
# 8787    2016
# 8788    2018
# 8789    2018
# Name: years, Length: 8790, dtype: int32

# %%
df["months"]=df["date_added"].dt.month_name()
df["months"]
# Out:
# 0       September
# 1       September
# 2       September
# 3       September
# 4       September
#           ...
# 8785      January
# 8786    September
# 8787     December
# 8788         June
# 8789         June
# Name: months, Length: 8790, dtype: object

# %%
days=df["date_added"].dt.day_name()
days
# Out:
# 0        Saturday
# 1          Friday
# 2          Friday
# 3       Wednesday
# 4          Friday
#           ...
# 8785      Tuesday
# 8786     Thursday
# 8787     Thursday
# 8788     Saturday
# 8789     Thursday
# Name: date_added, Length: 8790, dtype: object

# %%
cleaned=df["listed_in"].str.strip()
pd.DataFrame(cleaned)
# Out:
#                                               listed_in
# 0                                         Documentaries
# 1     Crime TV Shows, International TV Shows, TV Act...
# 2                    TV Dramas, TV Horror, TV Mysteries
# 3                    Children & Family Movies, Comedies
# 4      Dramas, Independent Movies, International Movies
# ...                                                 ...
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# 8788                                           Kids' TV
# 8789                                           Kids' TV
#
# [8790 rows x 1 columns]

# %%
cleaned2=df["country"].str.strip()
pd.DataFrame(cleaned2)
# Out:
#             country
# 0     United States
# 1            France
# 2     United States
# 3            Brazil
# 4     United States
# ...             ...
# 8785         Turkey
# 8786  United States
# 8787       Pakistan
# 8788       Pakistan
# 8789       Pakistan
#
# [8790 rows x 1 columns]

# %%
cleaned3=df["director"].str.strip()
pd.DataFrame(cleaned3)
# Out:
#              director
# 0     Kirsten Johnson
# 1     Julien Leclercq
# 2       Mike Flanagan
# 3       Bruno Garotti
# 4        Haile Gerima
# ...               ...
# 8785        Not Given
# 8786        Not Given
# 8787        Not Given
# 8788        Not Given
# 8789        Not Given
#
# [8790 rows x 1 columns]

# %%
df["director"].tail(2250)
# Out:
# 6540    Majid Al Ansari
# 6541      David Fincher
# 6542    Ruben Fleischer
# 6543       Peter Hewitt
# 6544        Mozez Singh
#              ...
# 8785          Not Given
# 8786          Not Given
# 8787          Not Given
# 8788          Not Given
# 8789          Not Given
# Name: director, Length: 2250, dtype: object

# %%
df["director"].value_counts()
# Out:
# director
# Not Given                                                        2588
# Rajiv Chilaka                                                      20
# Alastair Fothergill                                                18
# Raúl Campos, Jan Suter                                             18
# Marcus Raboy                                                       16
#                                                                  ...
# Majid Al Ansari                                                     1
# Peter Hewitt                                                        1
# Yasir Nawaz                                                         1
# Lawrence Kasdan                                                     1
# Jovanka Vuckovic, Annie Clark, Roxanne Benjamin, Karyn Kusama       1
# Name: count, Length: 4528, dtype: int64

# %%
missing_directors=df["director"].loc[6570:8790]
missing_directors
# Out:
# 6570    Not Given
# 6571    Not Given
# 6572    Not Given
# 6573    Not Given
# 6574    Not Given
#           ...
# 8785    Not Given
# 8786    Not Given
# 8787    Not Given
# 8788    Not Given
# 8789    Not Given
# Name: director, Length: 2220, dtype: object

# %%
type_count=df["type"].value_counts()
type_count
# Out:
# type
# Movie      6126
# TV Show    2664
# Name: count, dtype: int64

# %%
type_count.plot(kind='pie',autopct="%.0f%%")
plt.title(" Total content of movies and TV shows Netflix")
plt.legend()
plt.show()

# %%
df["listed_in"].head(10)
# Out:
# 0                                        Documentaries
# 1    Crime TV Shows, International TV Shows, TV Act...
# 2                   TV Dramas, TV Horror, TV Mysteries
# 3                   Children & Family Movies, Comedies
# 4     Dramas, Independent Movies, International Movies
# 5                         British TV Shows, Reality TV
# 6                                     Comedies, Dramas
# 7    Children & Family Movies, Comedies, Music & Mu...
# 8                         Dramas, International Movies
# 9           Children & Family Movies, Music & Musicals
# Name: listed_in, dtype: object

# %%
df["genre"]=df["listed_in"].str.split(",")
df["genre"]
# Out:
# 0                                         [Documentaries]
# 1       [Crime TV Shows,  International TV Shows,  TV ...
# 2                  [TV Dramas,  TV Horror,  TV Mysteries]
# 3                   [Children & Family Movies,  Comedies]
# 4       [Dramas,  Independent Movies,  International M...
#                               ...
# 8785                 [International TV Shows,  TV Dramas]
# 8786                                           [Kids' TV]
# 8787    [International TV Shows,  Romantic TV Shows,  ...
# 8788                                           [Kids' TV]
# 8789                                           [Kids' TV]
# Name: genre, Length: 8790, dtype: object

# %%
all_genres=[]
for gen in df["genre"]:
    for gens in gen:
        all_genres.append(gens.strip())
gens_count=pd.Series(all_genres).value_counts()
gens_count
# Out:
# International Movies            2752
# Dramas                          2426
# Comedies                        1674
# International TV Shows          1349
# Documentaries                    869
# Action & Adventure               859
# TV Dramas                        762
# Independent Movies               756
# Children & Family Movies         641
# Romantic Movies                  616
# Thrillers                        577
# TV Comedies                      573
# Crime TV Shows                   469
# Kids' TV                         448
# Docuseries                       394
# Music & Musicals                 375
# Romantic TV Shows                370
# Horror Movies                    357
# Stand-Up Comedy                  343
# Reality TV                       255
# British TV Shows                 252
# Sci-Fi & Fantasy                 243
# Sports Movies                    219
# Anime Series                     174
# Spanish-Language TV Shows        173
# ...

# %%
print(gens_count.head(10))
# Out:
# International Movies        2752
# Dramas                      2426
# Comedies                    1674
# International TV Shows      1349
# Documentaries                869
# Action & Adventure           859
# TV Dramas                    762
# Independent Movies           756
# Children & Family Movies     641
# Romantic Movies              616
# Name: count, dtype: int64

# %%
gens_count.head(10).plot(kind='barh',color='orange')
plt.title("Top popular genres")
plt.show()

# %%
#df.drop("gens_count",axis=1)
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country date_added  release_year rating   duration  \
# ...

# %%
df.groupby("type")["country"].count()
# Out:
# type
# Movie      6126
# TV Show    2664
# Name: country, dtype: int64

# %%
country_list = []
for countries in df['country']:
    for country in countries.split(','):
        country_list.append(country.strip())
country_counts = pd.Series(country_list).value_counts()
country_counts
# Out:
# United States     3240
# India             1057
# United Kingdom     638
# Pakistan           421
# Not Given          287
#                   ...
# Luxembourg           1
# Senegal              1
# Belarus              1
# Puerto Rico          1
# Cyprus               1
# Name: count, Length: 86, dtype: int64

# %%
country_counts.head(10).plot(kind='bar')
plt.title("top 10 country with most content")
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(x="years",data=df,palette='coolwarm')
plt.title("Content added over the time")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\kapur\AppData\Local\Temp\ipykernel_13620\690258489.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="years",data=df,palette='coolwarm')

# %%
top_directors=df["director"].value_counts().head(5)
pd.DataFrame(top_directors)
# Out:
#                         count
# director
# Not Given                2588
# Rajiv Chilaka              20
# Alastair Fothergill        18
# Raúl Campos, Jan Suter     18
# Marcus Raboy               16

# %%
top_directors.plot(kind='bar')
plt.title("top 5 directors of most content")
plt.show()

# %%
count_title=df.groupby("release_year")["title"].count().sort_values(ascending=False)
count_title
# Out:
# release_year
# 2018    1146
# 2017    1030
# 2019    1030
# 2020     953
# 2016     901
#         ...
# 1925       1
# 1947       1
# 1959       1
# 1966       1
# 1961       1
# Name: title, Length: 74, dtype: int64

# %%
count_title.head(10).plot(kind='bar',color='green')
plt.title("Titles per release year")
plt.ylabel("titles")
plt.show()

# %%
common_ratings=df.groupby("rating").count().sort_values(by="rating",ascending=False)
common_ratings
# Out:
#           show_id  type  title  director  country  date_added  release_year  \
# rating
# UR              3     3      3         3        3           3             3
# TV-Y7-FV        6     6      6         6        6           6             6
# TV-Y7         333   333    333       333      333         333           333
# TV-Y          306   306    306       306      306         306           306
# TV-PG         861   861    861       861      861         861           861
# TV-MA        3205  3205   3205      3205     3205        3205          3205
# TV-G          220   220    220       220      220         220           220
# TV-14        2157  2157   2157      2157     2157        2157          2157
# R             799   799    799       799      799         799           799
# PG-13         490   490    490       490      490         490           490
# PG            287   287    287       287      287         287           287
# ...

# %%
common_rating=df["rating"].value_counts()
common_rating
# Out:
# rating
# TV-MA       3205
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: count, dtype: int64

# %%
common_rating.plot(kind="line",marker='o',color='brown')
plt.title("most common rating")
plt.ylabel("frequency")
plt.show()

# %%
common_rating.head(8).plot(kind="pie",autopct="%.0f%%",fontsize=10)
plt.title("most common rating")
plt.show()

# %%
df.describe()
# Out:
#                           date_added  release_year        years       months
# count                           8790   8790.000000  8790.000000  8790.000000
# mean   2019-05-17 21:44:01.638225408   2014.183163  2018.873606     6.655859
# min              2008-01-01 00:00:00   1925.000000  2008.000000     1.000000
# 25%              2018-04-06 00:00:00   2013.000000  2018.000000     4.000000
# 50%              2019-07-03 00:00:00   2017.000000  2019.000000     7.000000
# 75%              2020-08-19 18:00:00   2019.000000  2020.000000    10.000000
# max              2021-09-25 00:00:00   2021.000000  2021.000000    12.000000
# std                              NaN      8.825466     1.573568     3.436103

# %%
df["release_year"].value_counts()
# Out:
# release_year
# 2018    1146
# 2019    1030
# 2017    1030
# 2020     953
# 2016     901
#         ...
# 1961       1
# 1959       1
# 1925       1
# 1966       1
# 1947       1
# Name: count, Length: 74, dtype: int64

# %%
movie_release=df.groupby("release_year")["type"].count().sort_values(ascending=False).head(10)
movie_release
# Out:
# release_year
# 2018    1146
# 2017    1030
# 2019    1030
# 2020     953
# 2016     901
# 2021     592
# 2015     555
# 2014     352
# 2013     286
# 2012     236
# Name: type, dtype: int64

# %%
movie_release.plot(kind='barh',color='red')
plt.title("most release of movies and shows by year")
plt.xlabel("count_type")
# Out:
# Text(0.5, 0, 'count_type')

# %%
movie_release.plot(kind='pie',autopct="%.0f%%",color='green')
plt.title("Yearly release of Movie and shows")
plt.show()

# %%
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country date_added  release_year rating   duration  \
# ...

# %%
monthly_release=df.groupby(df["months"])["type"].value_counts().sort_index()
monthly_release
# Out:
# months     type
# April      Movie      549
#            TV Show    214
# August     Movie      518
#            TV Show    236
# December   Movie      547
#            TV Show    265
# February   Movie      382
#            TV Show    180
# January    Movie      545
#            TV Show    192
# July       Movie      565
#            TV Show    262
# June       Movie      492
#            TV Show    236
# March      Movie      528
#            TV Show    213
# May        Movie      439
#            TV Show    193
# November   Movie      498
#            TV Show    207
# October    Movie      545
#            TV Show    215
# September  Movie      518
#            TV Show    251
# Name: count, dtype: int64

# %%
monthly_release.plot(kind='bar',color='purple')
plt.legend()
plt.ylabel("count of movie and shows released")
plt.title("Monthly release of Movie and shows")
plt.xticks(rotation=90)
plt.show()

# %%
movies_df = df[df['type'] == 'Movie'].copy()
movies_df = movies_df.dropna(subset=['duration'])
movies_df = movies_df[movies_df['duration'].str.contains('min', na=False)]
movies_df['duration_minutes'] = movies_df['duration'].str.extract(r'(\d+)')
movies_df = movies_df.dropna(subset=['duration_minutes'])
movies_df['duration_minutes'] = movies_df['duration_minutes'].astype(int)
average_duration = movies_df['duration_minutes'].mean()
print("Average movie duration:",round(average_duration,2),"minutes")
# Out:
# Average movie duration: 99.58 minutes

# %%
average_duration=99.58
avg_series=pd.Series([average_duration],index=['Average movie duration'])
avg_series.plot(kind='bar',figsize=(6,4))
plt.title("Average duration of movies")
plt.show()

# %%
movies_df['duration_minutes'].plot(kind='hist',bins=20,color='green')
plt.title("distribution of Movie durations")
plt.show()

# %%
high_content_month=df.groupby("months")["genre"].count().sort_values(ascending=False)
high_content_month
# Out:
# months
# July         827
# December     812
# September    769
# April        763
# October      760
# August       754
# March        741
# January      737
# June         728
# November     705
# May          632
# February     562
# Name: genre, dtype: int64

# %%
high_content_month.head(5).plot(kind='line',grid=True,marker='*',color='orange')
plt.title("highest content addition trend")
plt.ylabel("count")
plt.show()
